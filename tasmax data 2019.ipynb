# %%
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np 
import matplotlib.image as mpimg
import netCDF4 as nc

# %%
files =['tasmax_hadukgrid_uk_12km_day_20190101-20190131.nc',
'tasmax_hadukgrid_uk_12km_day_20191201-20191231.nc',
'tasmax_hadukgrid_uk_12km_day_20190201-20190228.nc',
'tasmax_hadukgrid_uk_12km_day_20190301-20190331.nc',
'tasmax_hadukgrid_uk_12km_day_20190501-20190531.nc',
'tasmax_hadukgrid_uk_12km_day_20190401-20190430.nc',
'tasmax_hadukgrid_uk_12km_day_20190601-20190630.nc',
'tasmax_hadukgrid_uk_12km_day_20190701-20190731.nc',
'tasmax_hadukgrid_uk_12km_day_20190901-20190930.nc',
'tasmax_hadukgrid_uk_12km_day_20190801-20190831.nc',
'tasmax_hadukgrid_uk_12km_day_20191001-20191031.nc',
'tasmax_hadukgrid_uk_12km_day_20191101-20191130.nc']
prefix= '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /'
urls=[prefix+file for file in files]
urls
# Out:
# ['/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20190101-20190131.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20191201-20191231.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20190201-20190228.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20190301-20190331.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20190501-20190531.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20190401-20190430.nc',
# ...

# %%
ds=xr.open_mfdataset(urls)

# %%
plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
ds.tasmax[0,:].plot.imshow(ax=ax)
ax.coastlines(resolution='50m')
ax.gridlines()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:387: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   return matplotlib.axes.Axes.draw(self, renderer=renderer,

# %%
ds.nbytes/1000*3
# Out:
# 84326.86799999999

# %%
tasmax=ds.tasmax

# %%
tasmax
# Out:
# <xarray.DataArray 'tasmax' (time: 365, projection_y_coordinate: 112, projection_x_coordinate: 82)>
# dask.array<concatenate, shape=(365, 112, 82), dtype=float64, chunksize=(31, 112, 82), chunktype=numpy.ndarray>
# Coordinates:
#   * time                     (time) datetime64[ns] 2019-01-01T12:00:00 ... 20...
#   * projection_y_coordinate  (projection_y_coordinate) float64 -1.02e+05 ... ...
#   * projection_x_coordinate  (projection_x_coordinate) float64 -2.1e+05 ... 7...
#     latitude                 (projection_y_coordinate, projection_x_coordinate) float64 dask.array<chunksize=(112, 82), meta=np.ndarray>
#     longitude                (projection_y_coordinate, projection_x_coordinate) float64 dask.array<chunksize=(112, 82), meta=np.ndarray>
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Maximum air temperature
#     units:          degC
#     description:    Maximum air temperature
#     label_units:    C
#     level:          1.5m
# ...

# %%
x=[0,32,60,91,121,152,182,213,244,274,305,335,366]

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[0].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[32].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()
plt.figure()

ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[60].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[91].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[121].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[152].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[182].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[213].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[244].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[274].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[305].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()

plt.figure()
ax = plt.axes(projection=ccrs.OSGB())
im=ds.tasmax[335].plot.imshow(ax=ax)
im.set_clim(0,40)
ax.coastlines(resolution='50m')
ax.gridlines()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:387: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   return matplotlib.axes.Axes.draw(self, renderer=renderer,

# %%
x=[0,31,59,90,120,151,181,212,243,273,304,334]
for x in x: 
    plt.figure()
    ax = plt.axes(projection=ccrs.OSGB())
    im=ds.tasmax[x].plot.imshow(ax=ax, cmap='rainbow')
    im.set_clim(0,30)
    ax.coastlines(resolution='50m')
    ax.gridlines()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:387: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   return matplotlib.axes.Axes.draw(self, renderer=renderer,

# %%
tasmax_clim_jan=tasmax.sel(time=slice('2019-01-01T00:00:00','2019-01-31T23:59:59')).mean(dim='time')
tasmax_clim_feb=tasmax.sel(time=slice('2019-02-01T00:00:00','2019-02-28T23:59:59')).mean(dim='time')
tasmax_clim_mar=tasmax.sel(time=slice('2019-03-01T00:00:00','2019-03-31T23:59:59')).mean(dim='time')
tasmax_clim_apr=tasmax.sel(time=slice('2019-04-01T00:00:00','2019-04-30T23:59:59')).mean(dim='time')
tasmax_clim_may=tasmax.sel(time=slice('2019-05-01T00:00:00','2019-05-31T23:59:59')).mean(dim='time')
tasmax_clim_jun=tasmax.sel(time=slice('2019-06-01T00:00:00','2019-06-30T23:59:59')).mean(dim='time')
tasmax_clim_jul=tasmax.sel(time=slice('2019-07-01T00:00:00','2019-07-31T23:59:59')).mean(dim='time')
tasmax_clim_aug=tasmax.sel(time=slice('2019-08-01T00:00:00','2019-08-31T23:59:59')).mean(dim='time')
tasmax_clim_sep=tasmax.sel(time=slice('2019-09-01T00:00:00','2019-09-30T23:59:59')).mean(dim='time')
tasmax_clim_oct=tasmax.sel(time=slice('2019-10-01T00:00:00','2019-10-31T23:59:59')).mean(dim='time')
tasmax_clim_nov=tasmax.sel(time=slice('2019-11-01T00:00:00','2019-11-30T23:59:59')).mean(dim='time')
tasmax_clim_dec=tasmax.sel(time=slice('2019-12-01T00:00:00','2019-12-31T23:59:59')).mean(dim='time')

# %%
x=[tasmax_clim_jan,tasmax_clim_feb,tasmax_clim_mar,tasmax_clim_apr, tasmax_clim_may,tasmax_clim_jun, tasmax_clim_jul, tasmax_clim_aug, tasmax_clim_sep, tasmax_clim_oct, tasmax_clim_nov, tasmax_clim_dec]
y=['Average Temperature in January', 'Average Temperature in February', 'Average Temperature in March', 'Average Temperature in April', 'Average Temperature in May', 'Average Temperature in June', 'Average Temperature in July', 'Average Temperature in August', 'Average Temperature in September', 'Average Temperature in October', 'Average Temperature in November', 'Average Temperature in December']
for x,y in x,y: 
    plt.figure()
    ax = plt.axes(projection=ccrs.OSGB())
    im=x.plot.imshow(ax=ax, cmap='rainbow')
    plt.title(y)
    im.set_clim(0,30)
    ax.coastlines(resolution='50m')
    ax.gridlines()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-eb8d80d1a70c> in <module>
#       1 x=[tasmax_clim_jan,tasmax_clim_feb,tasmax_clim_mar,tasmax_clim_apr, tasmax_clim_may,tasmax_clim_jun, tasmax_clim_jul, tasmax_clim_aug, tasmax_clim_sep, tasmax_clim_oct, tasmax_clim_nov, tasmax_clim_dec]
#       2 y=['Average Temperature in January', 'Average Temperature in February', 'Average Temperature in March', 'Average Temperature in April', 'Average Temperature in May', 'Average Temperature in June', 'Average Temperature in July', 'Average Temperature in August', 'Average Temperature in September', 'Average Temperature in October', 'Average Temperature in November', 'Average Temperature in December']
# ----> 3 for x,y in x,y:
#       4     plt.figure()
#       5     ax = plt.axes(projection=ccrs.OSGB())
#
# ValueError: too many values to unpack (expected 2)
