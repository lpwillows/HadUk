# %%
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np 
import matplotlib.image as mpimg
import netCDF4 as nc

# %%
files =['tasmax_hadukgrid_uk_12km_day_20100101-20100131.nc',
'tasmax_hadukgrid_uk_12km_day_20100201-20100228.nc',
'tasmax_hadukgrid_uk_12km_day_20100301-20100331.nc',
'tasmax_hadukgrid_uk_12km_day_20100401-20100430.nc',
'tasmax_hadukgrid_uk_12km_day_20100501-20100531.nc',
'tasmax_hadukgrid_uk_12km_day_20100601-20100630.nc',
'tasmax_hadukgrid_uk_12km_day_20100701-20100731.nc',
'tasmax_hadukgrid_uk_12km_day_20100801-20100831.nc',
'tasmax_hadukgrid_uk_12km_day_20100901-20100930.nc',
'tasmax_hadukgrid_uk_12km_day_20101001-20101031.nc',
'tasmax_hadukgrid_uk_12km_day_20101101-20101130.nc',
'tasmax_hadukgrid_uk_12km_day_20101201-20101231.nc',
'tasmax_hadukgrid_uk_12km_day_20110101-20110131.nc',
'tasmax_hadukgrid_uk_12km_day_20110201-20110228.nc',
'tasmax_hadukgrid_uk_12km_day_20110301-20110331.nc',
'tasmax_hadukgrid_uk_12km_day_20110401-20110430.nc',
'tasmax_hadukgrid_uk_12km_day_20110501-20110531.nc',
'tasmax_hadukgrid_uk_12km_day_20110601-20110630.nc',
'tasmax_hadukgrid_uk_12km_day_20110701-20110731.nc',
'tasmax_hadukgrid_uk_12km_day_20110801-20110831.nc',
'tasmax_hadukgrid_uk_12km_day_20110901-20110930.nc',
'tasmax_hadukgrid_uk_12km_day_20111001-20111031.nc',
'tasmax_hadukgrid_uk_12km_day_20111101-20111130.nc',
'tasmax_hadukgrid_uk_12km_day_20111201-20111231.nc',
'tasmax_hadukgrid_uk_12km_day_20120101-20120131.nc',
'tasmax_hadukgrid_uk_12km_day_20120201-20120229.nc',
'tasmax_hadukgrid_uk_12km_day_20120301-20120331.nc',
'tasmax_hadukgrid_uk_12km_day_20120401-20120430.nc',
'tasmax_hadukgrid_uk_12km_day_20120501-20120531.nc',
'tasmax_hadukgrid_uk_12km_day_20120601-20120630.nc',
'tasmax_hadukgrid_uk_12km_day_20120701-20120731.nc',
'tasmax_hadukgrid_uk_12km_day_20120801-20120831.nc',
'tasmax_hadukgrid_uk_12km_day_20120901-20120930.nc',
'tasmax_hadukgrid_uk_12km_day_20121001-20121031.nc',
'tasmax_hadukgrid_uk_12km_day_20121101-20121130.nc',
'tasmax_hadukgrid_uk_12km_day_20121201-20121231.nc',
'tasmax_hadukgrid_uk_12km_day_20130101-20130131.nc',
'tasmax_hadukgrid_uk_12km_day_20130201-20130228.nc',
'tasmax_hadukgrid_uk_12km_day_20130301-20130331.nc',
'tasmax_hadukgrid_uk_12km_day_20130401-20130430.nc',
'tasmax_hadukgrid_uk_12km_day_20130501-20130531.nc',
'tasmax_hadukgrid_uk_12km_day_20130601-20130630.nc',
'tasmax_hadukgrid_uk_12km_day_20130701-20130731.nc',
'tasmax_hadukgrid_uk_12km_day_20130801-20130831.nc',
'tasmax_hadukgrid_uk_12km_day_20130901-20130930.nc',
'tasmax_hadukgrid_uk_12km_day_20131001-20131031.nc',
'tasmax_hadukgrid_uk_12km_day_20131101-20131130.nc',
'tasmax_hadukgrid_uk_12km_day_20131201-20131231.nc',
'tasmax_hadukgrid_uk_12km_day_20140101-20140131.nc',
'tasmax_hadukgrid_uk_12km_day_20140201-20140228.nc',
'tasmax_hadukgrid_uk_12km_day_20140301-20140331.nc',
'tasmax_hadukgrid_uk_12km_day_20140401-20140430.nc',
'tasmax_hadukgrid_uk_12km_day_20140501-20140531.nc',
'tasmax_hadukgrid_uk_12km_day_20140601-20140630.nc',
'tasmax_hadukgrid_uk_12km_day_20140701-20140731.nc',
'tasmax_hadukgrid_uk_12km_day_20140801-20140831.nc',
'tasmax_hadukgrid_uk_12km_day_20140901-20140930.nc',
'tasmax_hadukgrid_uk_12km_day_20141001-20141031.nc',
'tasmax_hadukgrid_uk_12km_day_20141101-20141130.nc',
'tasmax_hadukgrid_uk_12km_day_20141201-20141231.nc',
'tasmax_hadukgrid_uk_12km_day_20150101-20150131.nc',
'tasmax_hadukgrid_uk_12km_day_20150201-20150228.nc',
'tasmax_hadukgrid_uk_12km_day_20150301-20150331.nc',
'tasmax_hadukgrid_uk_12km_day_20150401-20150430.nc',
'tasmax_hadukgrid_uk_12km_day_20150501-20150531.nc',
'tasmax_hadukgrid_uk_12km_day_20150601-20150630.nc',
'tasmax_hadukgrid_uk_12km_day_20150701-20150731.nc',
'tasmax_hadukgrid_uk_12km_day_20150801-20150831.nc',
'tasmax_hadukgrid_uk_12km_day_20150901-20150930.nc',
'tasmax_hadukgrid_uk_12km_day_20151001-20151031.nc',
'tasmax_hadukgrid_uk_12km_day_20151101-20151130.nc',
'tasmax_hadukgrid_uk_12km_day_20151201-20151231.nc',
'tasmax_hadukgrid_uk_12km_day_20160101-20160131.nc',
'tasmax_hadukgrid_uk_12km_day_20160201-20160229.nc',
'tasmax_hadukgrid_uk_12km_day_20160301-20160331.nc',
'tasmax_hadukgrid_uk_12km_day_20160401-20160430.nc',
'tasmax_hadukgrid_uk_12km_day_20160501-20160531.nc',
'tasmax_hadukgrid_uk_12km_day_20160601-20160630.nc',
'tasmax_hadukgrid_uk_12km_day_20160701-20160731.nc',
'tasmax_hadukgrid_uk_12km_day_20160801-20160831.nc',
'tasmax_hadukgrid_uk_12km_day_20160901-20160930.nc',
'tasmax_hadukgrid_uk_12km_day_20161001-20161031.nc',
'tasmax_hadukgrid_uk_12km_day_20161101-20161130.nc',
'tasmax_hadukgrid_uk_12km_day_20161201-20161231.nc',
'tasmax_hadukgrid_uk_12km_day_20170101-20170131.nc',
'tasmax_hadukgrid_uk_12km_day_20170201-20170228.nc',
'tasmax_hadukgrid_uk_12km_day_20170301-20170331.nc',
'tasmax_hadukgrid_uk_12km_day_20170401-20170430.nc',
'tasmax_hadukgrid_uk_12km_day_20170501-20170531.nc',
'tasmax_hadukgrid_uk_12km_day_20170601-20170630.nc',
'tasmax_hadukgrid_uk_12km_day_20170701-20170731.nc',
'tasmax_hadukgrid_uk_12km_day_20170801-20170831.nc',
'tasmax_hadukgrid_uk_12km_day_20170901-20170930.nc',
'tasmax_hadukgrid_uk_12km_day_20171001-20171031.nc',
'tasmax_hadukgrid_uk_12km_day_20171101-20171130.nc',
'tasmax_hadukgrid_uk_12km_day_20171201-20171231.nc',
'tasmax_hadukgrid_uk_12km_day_20180101-20180131.nc',
'tasmax_hadukgrid_uk_12km_day_20180201-20180228.nc',
'tasmax_hadukgrid_uk_12km_day_20180301-20180331.nc',
'tasmax_hadukgrid_uk_12km_day_20180401-20180430.nc',
'tasmax_hadukgrid_uk_12km_day_20180501-20180531.nc',
'tasmax_hadukgrid_uk_12km_day_20180601-20180630.nc',
'tasmax_hadukgrid_uk_12km_day_20180701-20180731.nc',
'tasmax_hadukgrid_uk_12km_day_20180801-20180831.nc',
'tasmax_hadukgrid_uk_12km_day_20180901-20180930.nc',
'tasmax_hadukgrid_uk_12km_day_20181001-20181031.nc',
'tasmax_hadukgrid_uk_12km_day_20181101-20181130.nc',
'tasmax_hadukgrid_uk_12km_day_20181201-20181231.nc',
'tasmax_hadukgrid_uk_12km_day_20190101-20190131.nc',
'tasmax_hadukgrid_uk_12km_day_20190201-20190228.nc',
'tasmax_hadukgrid_uk_12km_day_20190301-20190331.nc',
'tasmax_hadukgrid_uk_12km_day_20190401-20190430.nc',
'tasmax_hadukgrid_uk_12km_day_20190501-20190531.nc',
'tasmax_hadukgrid_uk_12km_day_20190601-20190630.nc',
'tasmax_hadukgrid_uk_12km_day_20190701-20190731.nc',
'tasmax_hadukgrid_uk_12km_day_20190801-20190831.nc',
'tasmax_hadukgrid_uk_12km_day_20190901-20190930.nc',
'tasmax_hadukgrid_uk_12km_day_20191001-20191031.nc',
'tasmax_hadukgrid_uk_12km_day_20191101-20191130.nc',
'tasmax_hadukgrid_uk_12km_day_20191201-20191231.nc']
prefix= '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /'
urls=[prefix+file for file in files]
urls
# Out:
# ['/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20100101-20100131.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20100201-20100228.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20100301-20100331.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20100401-20100430.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20100501-20100531.nc',
#  '/Users/lucy-paigewillows/Documents/Documents – Lucy-Paige’s MacBook Air/Final Project /tasmax_hadukgrid_uk_12km_day_20100601-20100630.nc',
# ...

# %%
ds=xr.open_mfdataset(urls)

# %%
tasmax=ds.tasmax

# %%
tasmax_clim_2010=tasmax.sel(time=slice('2010-01-01T00:00:00','2010-12-31T23:59:59')).mean(dim='time')
tasmax_clim_2011=tasmax.sel(time=slice('2011-01-01T00:00:00','2011-12-28T23:59:59')).mean(dim='time')
tasmax_clim_2012=tasmax.sel(time=slice('2012-01-01T00:00:00','2012-12-31T23:59:59')).mean(dim='time')
tasmax_clim_2013=tasmax.sel(time=slice('2013-01-01T00:00:00','2013-12-30T23:59:59')).mean(dim='time')
tasmax_clim_2014=tasmax.sel(time=slice('2014-01-01T00:00:00','2014-12-31T23:59:59')).mean(dim='time')
tasmax_clim_2015=tasmax.sel(time=slice('2015-01-01T00:00:00','2015-12-30T23:59:59')).mean(dim='time')
tasmax_clim_2016=tasmax.sel(time=slice('2016-01-01T00:00:00','2016-12-31T23:59:59')).mean(dim='time')
tasmax_clim_2017=tasmax.sel(time=slice('2017-01-01T00:00:00','2017-12-31T23:59:59')).mean(dim='time')
tasmax_clim_2018=tasmax.sel(time=slice('2018-01-01T00:00:00','2018-12-30T23:59:59')).mean(dim='time')
tasmax_clim_2019=tasmax.sel(time=slice('2019-01-01T00:00:00','2019-12-30T23:59:59')).mean(dim='time')

# %%
x=[tasmax_clim_2010,tasmax_clim_2011, tasmax_clim_2012,tasmax_clim_2013,tasmax_clim_2014, tasmax_clim_2015,tasmax_clim_2016, tasmax_clim_2017, tasmax_clim_2018, tasmax_clim_2019]
y=['Average Temperature in 2010', 'Average Temperature in 2011', 'Average Temperature in 2012', 'Average Temperature in 2013', 'Average Temperature in 2014', 'Average Temperature in 2015', 'Average Temperature in 2016', 'Average Temperature in 2017', 'Average Temperature in 2018', 'Average Temperature in 2019']
for i in range(10):
    variable = x[i]
    title = y[i]
    plt.figure()
    ax = plt.axes(projection=ccrs.OSGB())
    im=variable.plot.imshow(ax=ax, cmap='rainbow')
    im.set_clim(8,18)
    ax.coastlines(resolution='50m')
    ax.gridlines()
    plt.title(title)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ...

# %%
ax=tasmax_clim_2010.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000)).plot.imshow(size=10)
plt.annotate('Exeter', (310000,100000))
plt.annotate('Plymouth', (240000,65000))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Text(240000, 65000, 'Plymouth')

# %%
tasmax_clim_2010_slice_sw=tasmax_clim_2010.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))
tasmax_clim_2011_slice_sw=tasmax_clim_2011.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))
tasmax_clim_2012_slice_sw=tasmax_clim_2012.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))
tasmax_clim_2013_slice_sw=tasmax_clim_2013.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))
tasmax_clim_2014_slice_sw=tasmax_clim_2014.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))
tasmax_clim_2015_slice_sw=tasmax_clim_2015.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))
tasmax_clim_2016_slice_sw=tasmax_clim_2016.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))
tasmax_clim_2017_slice_sw=tasmax_clim_2017.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))
tasmax_clim_2018_slice_sw=tasmax_clim_2018.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))
tasmax_clim_2019_slice_sw=tasmax_clim_2019.sel(projection_x_coordinate=slice(200000,400000)).sel(projection_y_coordinate= slice(0,200000))

# %%
x=[tasmax_clim_2010_slice_sw,tasmax_clim_2011_slice_sw, tasmax_clim_2012_slice_sw,tasmax_clim_2013_slice_sw,tasmax_clim_2014_slice_sw, tasmax_clim_2015_slice_sw,tasmax_clim_2016_slice_sw, tasmax_clim_2017_slice_sw, tasmax_clim_2018_slice_sw, tasmax_clim_2019_slice_sw]
y=['Average Temperature in 2010 in South West', 'Average Temperature in 2011 in South West', 'Average Temperature in 2012 in South West', 'Average Temperature in 2013 in South West', 'Average Temperature in 2014 in South West', 'Average Temperature in 2015 in South West', 'Average Temperature in 2016 in South West', 'Average Temperature in 2017 in South West', 'Average Temperature in 2018 in South West', 'Average Temperature in 2019 in South West']
for i in range(10):
    variable = x[i]
    title = y[i]
    plt.figure()
    ax = plt.axes(projection=ccrs.OSGB())
    im=variable.plot.imshow(ax=ax, cmap='rainbow')
    im.set_clim(10,18)
    ax.coastlines(resolution='50m')
    ax.gridlines()
    plt.annotate('Exeter', (310000,100000))
    plt.annotate('Plymouth', (240000,65000))
    plt.title(title)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ...

# %%
tasmax_clim_2010_slice_sc=tasmax_clim_2010.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000)).plot.imshow()
plt.annotate('Edinburgh', (320000,650000))
plt.annotate('Glasgow', (250000,650000))
plt.annotate('Dundee', (340000,720000))
plt.annotate('Aberdeen', (380000,800000))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Text(380000, 800000, 'Aberdeen')

# %%
tasmax_clim_2010_slice_sc=tasmax_clim_2010.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))
tasmax_clim_2011_slice_sc=tasmax_clim_2011.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))
tasmax_clim_2012_slice_sc=tasmax_clim_2012.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))
tasmax_clim_2013_slice_sc=tasmax_clim_2013.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))
tasmax_clim_2014_slice_sc=tasmax_clim_2014.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))
tasmax_clim_2015_slice_sc=tasmax_clim_2015.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))
tasmax_clim_2016_slice_sc=tasmax_clim_2016.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))
tasmax_clim_2017_slice_sc=tasmax_clim_2017.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))
tasmax_clim_2018_slice_sc=tasmax_clim_2018.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))
tasmax_clim_2019_slice_sc=tasmax_clim_2019.sel(projection_x_coordinate=slice(100000,450000)).sel(projection_y_coordinate= slice(600000,1000000))

# %%
x=[tasmax_clim_2010_slice_sc,tasmax_clim_2011_slice_sc, tasmax_clim_2012_slice_sc,tasmax_clim_2013_slice_sc,tasmax_clim_2014_slice_sc, tasmax_clim_2015_slice_sc,tasmax_clim_2016_slice_sc, tasmax_clim_2017_slice_sc, tasmax_clim_2018_slice_sc, tasmax_clim_2019_slice_sc]
y=['Average Temperature in 2010 in Scotland', 'Average Temperature in 2011 in Scotland', 'Average Temperature in 2012 in Scotland', 'Average Temperature in 2013 in Scotland', 'Average Temperature in 2014 in Scotland', 'Average Temperature in 2015 in Scotland', 'Average Temperature in 2016 in Scotland', 'Average Temperature in 2017 in Scotland', 'Average Temperature in 2018 in Scotland', 'Average Temperature in 2019 in Scotland']
for i in range(10):
    variable = x[i]
    title = y[i]
    plt.figure()
    ax = plt.axes(projection=ccrs.OSGB())
    im=variable.plot.imshow(ax=ax, cmap='rainbow')
    im.set_clim(5,15)
    ax.coastlines(resolution='50m')
    ax.gridlines()
    plt.annotate('Edinburgh', (320000,650000))
    plt.annotate('Glasgow', (220000,650000))
    plt.annotate('Dundee', (340000,720000))
    plt.annotate('Aberdeen', (380000,800000))
    plt.title(title)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ...

# %%
tasmax_clim_2010_slice_ir=tasmax_clim_2010.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000)).plot.imshow()
plt.annotate('Belfast', (140000,530000))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Text(140000, 530000, 'Belfast')

# %%
tasmax_clim_2010_slice_ir=tasmax_clim_2010.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))
tasmax_clim_2011_slice_ir=tasmax_clim_2011.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))
tasmax_clim_2012_slice_ir=tasmax_clim_2012.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))
tasmax_clim_2013_slice_ir=tasmax_clim_2013.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))
tasmax_clim_2014_slice_ir=tasmax_clim_2014.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))
tasmax_clim_2015_slice_ir=tasmax_clim_2015.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))
tasmax_clim_2016_slice_ir=tasmax_clim_2016.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))
tasmax_clim_2017_slice_ir=tasmax_clim_2017.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))
tasmax_clim_2018_slice_ir=tasmax_clim_2018.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))
tasmax_clim_2019_slice_ir=tasmax_clim_2019.sel(projection_x_coordinate=slice(0,200000)).sel(projection_y_coordinate= slice(450000,650000))

# %%
x=[tasmax_clim_2010_slice_ir,tasmax_clim_2011_slice_ir, tasmax_clim_2012_slice_ir,tasmax_clim_2013_slice_ir,tasmax_clim_2014_slice_ir, tasmax_clim_2015_slice_ir,tasmax_clim_2016_slice_ir, tasmax_clim_2017_slice_ir, tasmax_clim_2018_slice_ir, tasmax_clim_2019_slice_ir]
y=['Average Temperature in 2010 in Ireland', 'Average Temperature in 2011 in Ireland', 'Average Temperature in 2012 in Ireland', 'Average Temperature in 2013 in Ireland', 'Average Temperature in 2014 in Ireland', 'Average Temperature in 2015 in Ireland', 'Average Temperature in 2016 in Ireland', 'Average Temperature in 2017 in Ireland', 'Average Temperature in 2018 in Ireland', 'Average Temperature in 2019 in Ireland']
for i in range(10):
    variable = x[i]
    title = y[i]
    plt.figure()
    ax = plt.axes(projection=ccrs.OSGB())
    im=variable.plot.imshow(ax=ax, cmap='rainbow')
    im.set_clim(5,15)
    ax.coastlines(resolution='50m')
    ax.gridlines()
    plt.annotate('Belfast', (140000,530000))
    plt.title(title)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ...

# %%
tasmax_clim_2010_slice_wa=tasmax_clim_2010.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000)).plot.imshow()
plt.annotate('Cardiff', (310000,180000))
plt.annotate('Swansea', (250000,200000))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Text(250000, 200000, 'Swansea')

# %%
tasmax_clim_2010_slice_wa=tasmax_clim_2010.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))
tasmax_clim_2011_slice_wa=tasmax_clim_2011.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))
tasmax_clim_2012_slice_wa=tasmax_clim_2012.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))
tasmax_clim_2013_slice_wa=tasmax_clim_2013.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))
tasmax_clim_2014_slice_wa=tasmax_clim_2014.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))
tasmax_clim_2015_slice_wa=tasmax_clim_2015.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))
tasmax_clim_2016_slice_wa=tasmax_clim_2016.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))
tasmax_clim_2017_slice_wa=tasmax_clim_2017.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))
tasmax_clim_2018_slice_wa=tasmax_clim_2018.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))
tasmax_clim_2019_slice_wa=tasmax_clim_2019.sel(projection_x_coordinate=slice(150000,350000)).sel(projection_y_coordinate= slice(160000,410000))

# %%
x=[tasmax_clim_2010_slice_wa,tasmax_clim_2011_slice_wa, tasmax_clim_2012_slice_wa,tasmax_clim_2013_slice_wa,tasmax_clim_2014_slice_wa, tasmax_clim_2015_slice_wa,tasmax_clim_2016_slice_wa, tasmax_clim_2017_slice_wa, tasmax_clim_2018_slice_wa, tasmax_clim_2019_slice_wa]
y=['Average Temperature in 2010 in Wales', 'Average Temperature in 2011 in Wales', 'Average Temperature in 2012 in Wales', 'Average Temperature in 2013 in Wales', 'Average Temperature in 2014 in Wales', 'Average Temperature in 2015 in Wales', 'Average Temperature in 2016 in Wales', 'Average Temperature in 2017 in Wales', 'Average Temperature in 2018 in Wales', 'Average Temperature in 2019 in Wales']
for i in range(10):
    variable = x[i]
    title = y[i]
    plt.figure()
    ax = plt.axes(projection=ccrs.OSGB())
    im=variable.plot.imshow(ax=ax, cmap='rainbow')
    im.set_clim(10,16)
    ax.coastlines(resolution='50m')
    ax.gridlines()
    plt.annotate('Cardiff', (310000,180000))
    plt.annotate('Swansea', (260000,198000))
    plt.title(title)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ...

# %%
tasmax_clim_2010_slice_se=tasmax_clim_2010.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000)).plot.imshow()
plt.annotate('London', (530000,180000))
plt.annotate('Ipswitch', (620000,250000))
plt.annotate('Brighton', (510000,110000))
plt.annotate('Cambridge', (550000,275000))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Text(550000, 275000, 'Cambridge')

# %%
tasmax_clim_2010_slice_se=tasmax_clim_2010.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))
tasmax_clim_2011_slice_se=tasmax_clim_2011.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))
tasmax_clim_2012_slice_se=tasmax_clim_2012.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))
tasmax_clim_2013_slice_se=tasmax_clim_2013.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))
tasmax_clim_2014_slice_se=tasmax_clim_2014.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))
tasmax_clim_2015_slice_se=tasmax_clim_2015.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))
tasmax_clim_2016_slice_se=tasmax_clim_2016.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))
tasmax_clim_2017_slice_se=tasmax_clim_2017.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))
tasmax_clim_2018_slice_se=tasmax_clim_2018.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))
tasmax_clim_2019_slice_se=tasmax_clim_2019.sel(projection_x_coordinate=slice(490000,670000)).sel(projection_y_coordinate= slice(75000,360000))

# %%
x=[tasmax_clim_2010_slice_se,tasmax_clim_2011_slice_se, tasmax_clim_2012_slice_se,tasmax_clim_2013_slice_se,tasmax_clim_2014_slice_se, tasmax_clim_2015_slice_se,tasmax_clim_2016_slice_se, tasmax_clim_2017_slice_se, tasmax_clim_2018_slice_se, tasmax_clim_2019_slice_se]
y=['Average Temperature in 2010 in South East', 'Average Temperature in 2011 in South East', 'Average Temperature in 2012 in South East', 'Average Temperature in 2013 in South East', 'Average Temperature in 2014 in South East', 'Average Temperature in 2015 in South East', 'Average Temperature in 2016 in South East', 'Average Temperature in 2017 in South East', 'Average Temperature in 2018 in South East', 'Average Temperature in 2019 in South East']
for i in range(10):
    variable = x[i]
    title = y[i]
    plt.figure()
    ax = plt.axes(projection=ccrs.OSGB())
    im=variable.plot.imshow(ax=ax, cmap='rainbow')
    im.set_clim(10,18)
    ax.coastlines(resolution='50m')
    ax.gridlines()
    plt.annotate('London', (530000,180000))
    plt.annotate('Ipswitch', (620000,250000))
    plt.annotate('Brighton', (510000,110000))
    plt.annotate('Cambridge', (550000,275000))
    plt.title(title)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ...
